# %% [markdown]
# # Gérer l'Index

# %% [markdown]
# Dans ce module, nous récupérons l'index contenu dans le fichier "index.pkl" pour pouvoir récupérer la première image d'une scène.

# %%
import pandas as pd

from pathlib import Path
from PIL import Image

# %%
frames_folder = "../../data/tests/frames/"

# %%
df = pd.read_pickle("../../data/tests/index.pkl")

# %%
df
# Out:
#   video_name        preview_name  start  end
# 0     video1    video1_0_105.png      0  105
# 1     video1  video1_106_193.png    106  193
# 2     video1  video1_194_472.png    194  472

# %%
path = Path(frames_folder) / Path(df["preview_name"].iat[0])

Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=352x240 at 0x7820ED9E08E0>
